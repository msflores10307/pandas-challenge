# %%
import os
import pandas as pd
import csv

# %%
data_path = os.path.join(".","Resources","purchase_data.csv")

# %%
purchase_df = pd.read_csv(data_path)
purchase_df.tail()
# Out:
#      Purchase ID          SN  Age  Gender  Item ID  \
# 775          775  Aethedru70   21  Female       60
# 776          776      Iral74   21    Male      164
# 777          777  Yathecal72   20    Male       67
# 778          778     Sisur91    7    Male       92
# 779          779   Ennrian78   24    Male       50
#
#                                  Item Name  Price
# 775                                   Wolf   3.54
# 776                       Exiled Doomblade   1.63
# 777  Celeste, Incarnation of the Corrupted   3.46
# 778                           Final Critic   4.19
# 779                                   Dawn   4.60

# %%
## Number of Unique Players
sn = purchase_df["SN"].unique()
player_count = len(sn)
player_count
# Out:
# 576

# %%
## Number of Unique Items
itemid = purchase_df["Item ID"].unique()
item_count = len(itemid)
print(item_count)
# Out:
# 179

# %%
## Average Purchase Price
avg_price = purchase_df["Price"].mean()
avg_price
# Out:
# 3.050987179487176

# %%
## Total Purchases
purchase_id = purchase_df["Purchase ID"]
purchase_count = len(purchase_id)
purchase_count
# Out:
# 780

# %%
## Total Revenue
price_df = purchase_df["Price"]
total_revenue = price_df.sum()
total_revenue
# Out:
# 2379.77

# %%
# Gender Demographics
gender_agg = purchase_df.groupby("Gender")
gender_count = pd.DataFrame(gender_agg.count())
gender_count.head()
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
# Counts and Percentages by Gender
male_count = gender_count.loc['Male','SN']
female_count = gender_count.loc['Male','SN']
other_count = gender_count.loc['Other / Non-Disclosed','SN']
male_percent = 100*male_count/player_count
female_percent = 100*female_count/player_count
other_percent = 100*other_count/player_count

# %%
#Purchasing Analysis - Gender

# Purchase Count by Gender 
male_count = gender_count.loc['Male','Purchase ID']
female_count = gender_count.loc['Male','Purchase ID']
other_count = gender_count.loc['Other / Non-Disclosed','Purchase ID']

# %%
# Average Price Per Gender
gender_mean = pd.DataFrame(gender_agg.mean())
male_avgprice = gender_mean.loc['Male','Price']
female_avgprice = gender_mean.loc['Female','Price']
other_avgprice = gender_mean.loc['Other / Non-Disclosed','Price']

# %%
# Total Purchase Value Per Gender
gender_sum = pd.DataFrame(gender_agg.sum())
gender_sum
male_tot = gender_sum.loc['Male','Price']
female_tot = gender_sum.loc['Female','Price']
other_tot = gender_sum.loc['Other / Non-Disclosed','Price']

# %%
# Age Binning
#purchase_df.describe() # min 7, max 45
age_bounds = [0,9,14,19,24,29,34,39,44,49]
age_names = ['Below 10','10-14','15-19','20-24','25-29','30-34','35-39','40-44','45-49']
purchase_df["Age Group"] = pd.cut(purchase_df["Age"], age_bounds, labels=age_names)
purchase_df.loc[purchase_df['Age'] == 19]
# Out:
#      Purchase ID              SN  Age  Gender  Item ID  \
# 30            30          Idai61   19    Male      140
# 34            34        Sondim73   19    Male      160
# 59            59        Yaliru88   19    Male      105
# 94            94          Aina43   19    Male       96
# 108          108    Sondadarya58   19    Male       85
# 129          129        Lisast87   19    Male       74
# 219          219         Aidai53   19    Male       57
# 233          233      Taeduenu92   19  Female       66
# 281          281      Sondimla25   19    Male       68
# 345          345          Hada39   19    Male        2
# 370          370          Idai61   19    Male       45
# 399          399    Marilsasya33   19    Male      143
# 407          407          Idai61   19    Male      131
# 452          452    Marilsasya33   19    Male       32
# 505          505    Thourdirra92   19    Male      110
# 533          533          Hada39   19    Male       48
# ...

# %%
age_agg = purchase_df.groupby("Age Group")
age_mean = pd.DataFrame(age_agg.mean())
age_count = pd.DataFrame(age_agg.count())
age_sum = pd.DataFrame(age_agg.sum())

# %%
age_purchases = age_count.loc[:,'Purchase ID']
age_avgprice = age_mean.loc[:,'Price']
age_tot = age_sum.loc[:,'Price']
age_avgtotal = age_tot/age_count.loc[:,'SN']
# Out:
# Age Group
# Below 10    3.353478
# 10-14       2.956429
# 15-19       3.035956
# 20-24       3.052219
# 25-29       2.900990
# 30-34       2.931507
# 35-39       3.601707
# 40-44       3.045000
# 45-49       1.700000
# dtype: float64

# %%
age_avgprice
# Out:
# Age Group
# Below 10    3.353478
# 10-14       2.956429
# 15-19       3.035956
# 20-24       3.052219
# 25-29       2.900990
# 30-34       2.931507
# 35-39       3.601707
# 40-44       3.045000
# 45-49       1.700000
# Name: Price, dtype: float64

# %%
player_agg = purchase_df.groupby('SN')
player_count = player_agg.count()
player_tot = player_agg.sum().sort_values("Price", ascending = False)
player_avgprice = player_agg.mean()
player_join = player_tot.merge(player_avgprice,on = 'SN', suffixes = ['_tot','_avg'])
player_join2 = player_join.merge(player_count, on = 'SN').sort_values("Price_tot", ascending = False)
player_join2.head()
player_join2['Age','Price_avg','Price_tot'] #for some reason i'm having issues indexing from player_join2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('Age', 'Price_avg', 'Price_tot')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-195-02cde1eb3c4a> in <module>
# ...

# %%
item_agg = purchase_df.groupby('Item Name')
item_count = item_agg.count()
item_tot = item_agg.sum()
